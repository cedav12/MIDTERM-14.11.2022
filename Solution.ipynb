# %% [markdown]
# # Midterm solution

# %%
#Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
STE = pd.read_csv("STE.csv")
STE
# Out:
#             Date        High         Low        Open       Close    Volume  \
# 0     2017-11-13   87.699997   86.019997   86.580002   87.529999  353400.0
# 1     2017-11-14   88.309998   86.949997   87.320000   88.260002  315900.0
# 2     2017-11-15   87.949997   86.959999   87.790001   87.610001  241100.0
# 3     2017-11-16   88.449997   87.599998   87.839996   87.889999  320800.0
# 4     2017-11-17   88.059998   87.180000   87.449997   87.849998  245500.0
# ...          ...         ...         ...         ...         ...       ...
# 1254  2022-11-07  164.649994  160.690002  164.539993  163.570007  806900.0
# 1255  2022-11-08  165.779999  160.789993  164.000000  163.589996  688900.0
# 1256  2022-11-09  164.940002  160.149994  163.210007  160.979996  771300.0
# 1257  2022-11-10  169.899994  161.339996  166.309998  169.270004  922000.0
# 1258  2022-11-11  172.919998  168.880005  168.880005  172.539993  773600.0
#
#        Adj Close
# 0      83.676140
# 1      84.374016
# ...

# %%
TMUS = pd.read_csv("TMUS.csv")
TMUS
# Out:
#             Date        High         Low        Open       Close    Volume  \
# 0     2017-11-13   56.889999   55.910000   56.799999   56.439999   4429100
# 1     2017-11-14   56.959999   55.959999   56.389999   56.540001   5035300
# 2     2017-11-15   56.990002   56.180000   56.799999   56.689999   3709900
# 3     2017-11-16   59.980000   56.810001   56.810001   59.799999  10397700
# 4     2017-11-17   60.070000   58.959999   59.549999   60.020000   7147600
# ...          ...         ...         ...         ...         ...       ...
# 1254  2022-11-07  150.419998  148.830002  149.750000  149.779999   5150100
# 1255  2022-11-08  150.960007  148.419998  150.000000  149.899994   3246500
# 1256  2022-11-09  150.440002  148.440002  149.279999  148.639999   4848900
# 1257  2022-11-10  152.000000  148.139999  151.889999  150.449997   6440900
# 1258  2022-11-11  150.139999  145.050003  149.960007  146.190002   7576400
#
#        Adj Close
# 0      56.439999
# 1      56.540001
# ...

# %%
TTWO = pd.read_csv("TTWO.csv")
TTWO
# Out:
#             Date        High         Low        Open       Close    Volume  \
# 0     2017-11-13  119.169998  114.580002  114.690002  118.260002   2736100
# 1     2017-11-14  119.279999  117.349998  118.250000  118.879997   2160300
# 2     2017-11-15  118.800003  116.370003  117.900002  117.370003   1730400
# 3     2017-11-16  119.709999  118.099998  118.949997  118.900002   1837000
# 4     2017-11-17  119.389999  116.360001  118.680000  117.820000   3142300
# ...          ...         ...         ...         ...         ...       ...
# 1254  2022-11-07  109.389999  106.220001  108.599998  108.400002   5450700
# 1255  2022-11-08   98.949997   90.000000   91.900002   93.570000  19320500
# 1256  2022-11-09   95.570000   92.760002   93.269997   94.089996   3967800
# 1257  2022-11-10   99.650002   96.250000   98.419998   98.570000   3100500
# 1258  2022-11-11  104.050003   98.160004   98.949997  102.250000   4107000
#
#        Adj Close
# 0     118.260002
# 1     118.879997
# ...

# %% [markdown]
# ## 1.1
#
# Is there any company with no difference between close price and adj. close price?

# %%
print((STE["Close"] == STE["Adj Close"]).sum() == STE.shape[0])
print((TMUS["Close"] == TMUS["Adj Close"]).sum() == TMUS.shape[0])
print((TTWO["Close"] == TTWO["Adj Close"]).sum() == TTWO.shape[0])
# Out:
# False
# True
# True

# %% [markdown]
# Companies TMUS and TTWO have for each observation same close and adjusted close price. This means that the first company STE needed to adjust its closing price from dividents and splits.

# %% [markdown]
# ## 1.2
#
# Highest and lowest adj close price for each company recorded.

# %%
print("STE")
print(STE["Adj Close"].describe())
print("TMUS")
print(TMUS["Adj Close"].describe())
print("TWO")
print(TTWO["Adj Close"].describe())
# Out:
# STE
# count    1259.000000
# mean      159.351031
# std        46.816367
# min        80.767281
# 25%       116.598095
# 50%       151.967468
# 75%       203.029945
# max       252.919998
# Name: Adj Close, dtype: float64
# TMUS
# count    1259.000000
# mean       99.078094
# std        29.854382
# min        55.580002
# 25%        70.010002
# 50%        98.139999
# 75%       127.764999
# max       152.279999
# Name: Adj Close, dtype: float64
# TWO
# count    1259.000000
# mean      136.292319
# std        28.986673
# min        84.629997
# 25%       114.584999
# 50%       126.699997
# 75%       162.165001
# max       213.339996
# Name: Adj Close, dtype: float64

# %% [markdown]
# Minimal and maximal closing price could be seen above

# %% [markdown]
# ## 1.3
#
# Logarhitmic returns.

# %%
STE["logreturns"] = np.log(STE['Adj Close']/STE['Adj Close'].shift(1))
print("STE log returns\n",STE["logreturns"])
TMUS["logreturns"] = np.log(TMUS['Adj Close']/TMUS['Adj Close'].shift(1))
print("\nTMUS log returns\n",TMUS["logreturns"])
TTWO["logreturns"] = np.log(TTWO['Adj Close']/TTWO['Adj Close'].shift(1))
print("\nTTWO logreturns\n",TTWO["logreturns"])
# Out:
# STE log returns
#  0            NaN
# 1       0.008306
# 2      -0.007392
# 3       0.003191
# 4      -0.000455
#           ...
# 1254    0.003859
# 1255    0.000122
# 1256   -0.016083
# 1257    0.050215
# 1258    0.019134
# Name: logreturns, Length: 1259, dtype: float64
#
# TMUS log returns
#  0            NaN
# 1       0.001770
# 2       0.002649
# 3       0.053408
# 4       0.003672
#           ...
# 1254    0.006363
# 1255    0.000801
# 1256   -0.008441
# 1257    0.012104
# 1258   -0.028724
# Name: logreturns, Length: 1259, dtype: float64
#
# TTWO logreturns
#  0            NaN
# 1       0.005229
# 2      -0.012783
# 3       0.012951
# 4      -0.009125
#           ...
# 1254   -0.001199
# 1255   -0.147118
# 1256    0.005542
# 1257    0.046515
# 1258    0.036654
# Name: logreturns, Length: 1259, dtype: float64

# %% [markdown]
# descriptive statistics of logreturns

# %%
print("STE log returns\n")
print(STE["logreturns"].describe())
print("\nTMUS log returns\n")
print(TMUS["logreturns"].describe())
print("\nTTWO log returns\n")
print(TTWO["logreturns"].describe())
# Out:
# STE log returns
#
# count    1258.000000
# mean        0.000575
# std         0.017177
# min        -0.123135
# 25%        -0.007000
# 50%         0.001342
# 75%         0.009573
# max         0.095372
# Name: logreturns, dtype: float64
#
# TMUS log returns
#
# count    1258.000000
# mean        0.000757
# std         0.018156
# min        -0.118882
# 25%        -0.007986
# 50%         0.000994
# 75%         0.009269
# max         0.111387
# Name: logreturns, dtype: float64
#
# TTWO log returns
#
# count    1258.000000
# mean       -0.000116
# std         0.024307
# min        -0.148003
# 25%        -0.011316
# 50%         0.000732
# 75%         0.012543
# max         0.111355
# Name: logreturns, dtype: float64

# %% [markdown]
# ## 1.4
#
# Which day the company recorded highest gain/loss
#
#
# Firstly we will change the date from string to datetime and set date as an index.

# %%
#Changing the data type
STE["Date"] = pd.to_datetime(STE["Date"])
TMUS["Date"] = pd.to_datetime(TMUS["Date"])
TTWO["Date"] = pd.to_datetime(TTWO["Date"])

#Setting index
STE = STE.set_index("Date")
TMUS =TMUS.set_index("Date")
TTWO = TTWO.set_index("Date")

# %%
minmax = pd.DataFrame({"maximal logreturn": [STE["logreturns"].idxmax(),TMUS["logreturns"].idxmax(),TTWO["logreturns"].idxmax()],
                      "minimal logreturns" : [STE["logreturns"].idxmin(),TMUS["logreturns"].idxmin(),TTWO["logreturns"].idxmin()]},
                     index = ["STE", "TMUS", "TTWO"])

minmax
# Out:
#      maximal logreturn minimal logreturns
# STE         2020-03-26         2020-03-16
# TMUS        2020-02-11         2020-03-12
# TTWO        2022-05-17         2019-02-06

# %% [markdown]
# ## 1.5
#
# Average calendar weekly volume

# %%
print("STE: ",STE[STE.index.weekday != (5,6)]["Volume"].mean())
print("TMUS: ",TMUS[TMUS.index.weekday != (5,6)]["Volume"].mean())
print("TTWO: ",TTWO[TTWO.index.weekday != (5,6)]["Volume"].mean())
# Out:
# STE:  508685.86179507547
# TMUS:  4490314.535345512
# TTWO:  1949216.2827640986

# %% [markdown]
# ## 1.6
#
# The highest total return.

# %%
total_returns = {"STE" : STE["logreturns"].sum(),"TMUS" : TMUS["logreturns"].sum(),"TTWO" : TTWO["logreturns"].sum()}
print(total_returns)
# Out:
# {'STE': 0.7236751856040813, 'TMUS': 0.9517290595710137, 'TTWO': -0.1454648135336201}

# %% [markdown]
# TMUS made the highest returns

# %% [markdown]
# ## 1.7.

# %% [markdown]
# Plot log returns

# %%
plt.plot(STE["logreturns"], label = "STE")
plt.plot(TMUS["logreturns"], label = "TMUS")
plt.plot(TTWO["logreturns"], label = "TWO")
plt.legend()
plt.show()

# %% [markdown]
# ## 1.8

# %%
plt.hist(STE["logreturns"], label = "STE")
plt.hist(TMUS["logreturns"], label = "TMUS")
plt.hist(TTWO["logreturns"], label = "TTWO")

plt.legend()
plt.show()

# %% [markdown]
# ## 2.1
#
# How many companies did not include the column included.

# %%
#Load data
SP500 = pd.read_csv("https://ies-python-midterm.s3.eu-central-1.amazonaws.com/companies/companies_no_subindustry.csv")
SP500
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4     ABMD               Abiomed             Health Care
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                           hq    included      Founded
# 0      Saint Paul, Minnesota  09.08.1976         1902
# 1       Milwaukee, Wisconsin  26.07.2017         1916
# 2    North Chicago, Illinois  31.03.1964         1888
# 3    North Chicago, Illinois  31.12.2012  2013 (1888)
# ...

# %%
SP500["included"].isna().sum()
# Out:
# 45

# %% [markdown]
# Total 45 companies did not included the "included" column.

# %% [markdown]
# ## 2.2
#
# delete the companies with no "included" column

# %%
SP500[~SP500["included"].isna()]
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4     ABMD               Abiomed             Health Care
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                           hq    included      Founded
# 0      Saint Paul, Minnesota  09.08.1976         1902
# 1       Milwaukee, Wisconsin  26.07.2017         1916
# 2    North Chicago, Illinois  31.03.1964         1888
# 3    North Chicago, Illinois  31.12.2012  2013 (1888)
# ...

# %% [markdown]
# ### Unfortunately I had no time left :(
